# %%
/Users/kumarkeshav/Downloads/palmerpenguins_extended.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Users/kumarkeshav/Downloads/palmerpenguins_extended.csv()
#
# NameError: name 'Users' is not defined

# %%
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
import numpy as np

# %%
df = pd.read_csv("/Users/kumarkeshav/Downloads/palmerpenguins_extended.csv")

# %%
df.head()
# Out:
#   species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Biscoe            53.4           17.8              219.0
# 1  Adelie  Biscoe            49.3           18.1              245.0
# 2  Adelie  Biscoe            55.7           16.6              226.0
# 3  Adelie  Biscoe            38.0           15.6              221.0
# 4  Adelie  Biscoe            60.7           17.9              177.0
#
#    body_mass_g     sex  diet life_stage health_metrics  year
# 0       5687.0  female  fish      adult     overweight  2021
# 1       6811.0  female  fish      adult     overweight  2021
# 2       5388.0  female  fish      adult     overweight  2021
# 3       6262.0  female  fish      adult     overweight  2021
# 4       4811.0  female  fish   juvenile     overweight  2021

# %%
import matplotlib.pyplot as plt
# Out:
# python(64453) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(64454) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Matplotlib is building the font cache; this may take a moment.

# %%
x = df['flipper_length_mm']
y = df['body_mass_g']

# %%
plt.scatter(x,y,c = df['color'])

# %%
df.shape
# Out:
# (3430, 11)

# %%
pd.unique(df['species'])
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
for i in range(max(df.index)):
    if df.loc[i,'species'] == 'Adelie':
        df.loc[i,'color']='Red'
    elif df.loc[i,'species'] == 'Chinstrap':
        df.loc[i,'color']='Blue'
    else: 
        df.loc[i,'color']='Green'

# %%
for i in range(max(df.index)):
    if df['species'].iloc[i] == 'Adelie':
        print('Red')
    elif df['species'].iloc[i] == 'Chinstrap':
        print('Blue')
    else: 
        print('Green')

# %%
df.head()
# Out:
#   species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Biscoe            53.4           17.8              219.0
# 1  Adelie  Biscoe            49.3           18.1              245.0
# 2  Adelie  Biscoe            55.7           16.6              226.0
# 3  Adelie  Biscoe            38.0           15.6              221.0
# 4  Adelie  Biscoe            60.7           17.9              177.0
#
#    body_mass_g     sex  diet life_stage health_metrics  year color
# 0       5687.0  female  fish      adult     overweight  2021   Red
# 1       6811.0  female  fish      adult     overweight  2021   Red
# 2       5388.0  female  fish      adult     overweight  2021   Red
# 3       6262.0  female  fish      adult     overweight  2021   Red
# 4       4811.0  female  fish   juvenile     overweight  2021   Red

# %%
df1 = df[df['species']=='Adelie']

# %%
df1.head()
# Out:
#   species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Biscoe            53.4           17.8              219.0
# 1  Adelie  Biscoe            49.3           18.1              245.0
# 2  Adelie  Biscoe            55.7           16.6              226.0
# 3  Adelie  Biscoe            38.0           15.6              221.0
# 4  Adelie  Biscoe            60.7           17.9              177.0
#
#    body_mass_g     sex  diet life_stage health_metrics  year color
# 0       5687.0  female  fish      adult     overweight  2021   Red
# 1       6811.0  female  fish      adult     overweight  2021   Red
# 2       5388.0  female  fish      adult     overweight  2021   Red
# 3       6262.0  female  fish      adult     overweight  2021   Red
# 4       4811.0  female  fish   juvenile     overweight  2021   Red

# %%
df1.shape
# Out:
# (1560, 12)

# %%
df2 = df[df['species']=='Chinstrap']

# %%
df2.shape
# Out:
# (623, 12)

# %%
df3 = df[(df['species']!='Adelie') &  (df['species']!='Chinstrap')]

# %%
df3.head()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 227  Gentoo  Biscoe            51.3           23.3              231.0
# 228  Gentoo  Biscoe            56.8           20.6              246.0
# 229  Gentoo  Biscoe            66.5           24.0              259.0
# 230  Gentoo  Biscoe            56.9           21.6              204.0
# 231  Gentoo  Biscoe            50.2           18.7              214.0
#
#      body_mass_g     sex  diet life_stage health_metrics  year  color
# 227       5536.0  female  fish      adult        healthy  2021  Green
# 228       5718.0  female  fish      adult        healthy  2021  Green
# 229       6711.0  female  fish      adult     overweight  2021  Green
# 230       6499.0  female  fish      adult     overweight  2021  Green
# 231       5733.0  female  fish   juvenile     overweight  2021  Green

# %%
df3.shape
# Out:
# (1247, 12)

# %%
plt.scatter(df1['flipper_length_mm'],df1['body_mass_g'],s=1)
plt.scatter(df2['flipper_length_mm'],df2['body_mass_g'],s=1)
plt.scatter(df3['flipper_length_mm'],df3['body_mass_g'],s=1)

# %%
print("\"Hello'")
# Out:
# "Hello'

# %%
x = '123'
type(int(x))
# Out:
# int

# %%
a=10 
b=3
print(int(a/b))
print(a%b)
print(a**b)
# Out:
# 3
# 1
# 1000
